# %% [markdown]
# ## **Author : Loka Akash Reddy**
# ### **LGM VIP - Data Science September-2021**
# ### **Task 4-Image to Pencil Sketch with Python**

# %% [markdown]
# ### **Importing essential libraries**

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Read the image**

# %%
image = cv2.imread("//content/Cristiano_Ronaldo_2018.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=614x921 at 0x7F6652DDC2D0>

# %% [markdown]
# ### Now we will create a new image by converting the original image to greyscale:

# %%
# converting image from RGB to GRAY scale image
gray_scale_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) 
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=614x921 at 0x7F664383E550>

# %%
# using bitwise_not func to invert the image
inverted_image = cv2.bitwise_not(gray_scale_image)
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=614x921 at 0x7F664383EAD0>

# %% [markdown]
# ### **Now the next step in the process is to blur the image by using the Gaussian Function in OpenCV:**

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=614x921 at 0x7F664384A590>

# %% [markdown]
# ### **Then the final step is to invert the blurred image, then we can easily convert the image into a pencil sketch:**

# %%
#dividing the greyscale value of the image by the inverse of blurred image value which highlights the boldest edges of an image
def pencil_sketch(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch=pencil_sketch(gray_scale_image,img_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=614x921 at 0x7F664ED26910>

# %% [markdown]
# ### **And finally, if we want to have a look at both the original image and the pencil sketch then here we can use the following commands:**

# %%
cv2_imshow(image) #original image
cv2_imshow(pencil_sketch) #pencil sketch
# Out:
# <PIL.Image.Image image mode=RGB size=614x921 at 0x7F6643849910>
# <PIL.Image.Image image mode=L size=614x921 at 0x7F6643849810>

# %% [markdown]
# ### **Thank You**
